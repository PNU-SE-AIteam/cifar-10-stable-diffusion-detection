# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.activations import swish
from tensorflow.keras.callbacks import TensorBoard
import time
import matplotlib.pyplot as plt
from matplotlib import gridspec
# !pip install keras_tuner -q

from distutils.dir_util import copy_tree
# Out:
# 2024-03-11 11:24:14.193772: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-11 11:24:14.193866: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-11 11:24:14.339252: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
destination_dir = "/kaggle/working/"


copy_tree("/kaggle/input/random-tuner-1-1/", destination_dir)
# Out:
# ['/kaggle/working/projects/cifake_random_1/trial_2/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_2/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_2/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_09/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_09/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_09/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_5/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_5/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_5/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_11/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_11/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_11/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_10/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_10/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_10/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/oracle.json',
#  '/kaggle/working/projects/cifake_random_1/tuner0.json',
#  '/kaggle/working/projects/cifake_random_1/trial_0/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_0/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_0/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_07/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_07/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_07/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_4/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_4/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_4/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_1/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_1/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_1/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_6/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_6/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_6/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_3/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_3/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_3/build_config.json',
#  '/kaggle/working/projects/cifake_random_1/trial_08/trial.json',
#  '/kaggle/working/projects/cifake_random_1/trial_08/checkpoint.weights.h5',
#  '/kaggle/working/projects/cifake_random_1/trial_08/build_config.json',
#  '/kaggle/working/BESTcifakeCNN20240310-210934.keras',
#  '/kaggle/working/BESTcifakeCNN20240310-144409.keras',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution1/validation/events.out.tfevents.1710105768.f9f4e496da23.26.5.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution1/events.out.tfevents.1710105693.f9f4e496da23.26.3.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution1/train/events.out.tfevents.1710105693.f9f4e496da23.26.4.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution2/validation/events.out.tfevents.1710106445.f9f4e496da23.26.8.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution2/events.out.tfevents.1710106368.f9f4e496da23.26.6.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution2/train/events.out.tfevents.1710106368.f9f4e496da23.26.7.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution0/validation/events.out.tfevents.1710105264.f9f4e496da23.26.2.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution0/events.out.tfevents.1710105109.f9f4e496da23.26.0.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/07/execution0/train/events.out.tfevents.1710105109.f9f4e496da23.26.1.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution1/validation/events.out.tfevents.1710117175.f9f4e496da23.26.32.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution1/events.out.tfevents.1710117121.f9f4e496da23.26.30.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution1/train/events.out.tfevents.1710117122.f9f4e496da23.26.31.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution2/validation/events.out.tfevents.1710117585.f9f4e496da23.26.35.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution2/events.out.tfevents.1710117531.f9f4e496da23.26.33.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution2/train/events.out.tfevents.1710117532.f9f4e496da23.26.34.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution0/validation/events.out.tfevents.1710116762.f9f4e496da23.26.29.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution0/events.out.tfevents.1710116703.f9f4e496da23.26.27.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/10/execution0/train/events.out.tfevents.1710116704.f9f4e496da23.26.28.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution1/validation/events.out.tfevents.1710110222.f9f4e496da23.26.14.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution1/events.out.tfevents.1710109958.f9f4e496da23.26.12.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution1/train/events.out.tfevents.1710109959.f9f4e496da23.26.13.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution2/validation/events.out.tfevents.1710113139.f9f4e496da23.26.17.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution2/events.out.tfevents.1710112870.f9f4e496da23.26.15.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution2/train/events.out.tfevents.1710112871.f9f4e496da23.26.16.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution0/events.out.tfevents.1710107045.f9f4e496da23.26.9.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution0/validation/events.out.tfevents.1710107311.f9f4e496da23.26.11.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/08/execution0/train/events.out.tfevents.1710107045.f9f4e496da23.26.10.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution1/validation/events.out.tfevents.1710116140.f9f4e496da23.26.23.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution1/train/events.out.tfevents.1710116102.f9f4e496da23.26.22.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution1/events.out.tfevents.1710116101.f9f4e496da23.26.21.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution2/validation/events.out.tfevents.1710116443.f9f4e496da23.26.26.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution2/events.out.tfevents.1710116404.f9f4e496da23.26.24.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution2/train/events.out.tfevents.1710116405.f9f4e496da23.26.25.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution0/validation/events.out.tfevents.1710115841.f9f4e496da23.26.20.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution0/events.out.tfevents.1710115798.f9f4e496da23.26.18.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/09/execution0/train/events.out.tfevents.1710115799.f9f4e496da23.26.19.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution1/validation/events.out.tfevents.1710119119.f9f4e496da23.26.41.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution1/events.out.tfevents.1710119025.f9f4e496da23.26.39.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution1/train/events.out.tfevents.1710119026.f9f4e496da23.26.40.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution2/validation/events.out.tfevents.1710120049.f9f4e496da23.26.44.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution2/events.out.tfevents.1710119955.f9f4e496da23.26.42.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution2/train/events.out.tfevents.1710119956.f9f4e496da23.26.43.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution0/validation/events.out.tfevents.1710118046.f9f4e496da23.26.38.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution0/events.out.tfevents.1710117947.f9f4e496da23.26.36.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-210934/11/execution0/train/events.out.tfevents.1710117949.f9f4e496da23.26.37.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution1/events.out.tfevents.1710083384.600bf98cbba4.26.3.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution1/validation/events.out.tfevents.1710083463.600bf98cbba4.26.5.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution1/train/events.out.tfevents.1710083385.600bf98cbba4.26.4.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution2/validation/events.out.tfevents.1710084216.600bf98cbba4.26.8.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution2/events.out.tfevents.1710084136.600bf98cbba4.26.6.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution2/train/events.out.tfevents.1710084137.600bf98cbba4.26.7.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution0/validation/events.out.tfevents.1710082139.600bf98cbba4.26.2.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution0/events.out.tfevents.1710081986.600bf98cbba4.26.0.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/5/execution0/train/events.out.tfevents.1710081986.600bf98cbba4.26.1.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution1/validation/events.out.tfevents.1710085855.600bf98cbba4.26.14.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution1/events.out.tfevents.1710085752.600bf98cbba4.26.12.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution1/train/events.out.tfevents.1710085753.600bf98cbba4.26.13.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution2/validation/events.out.tfevents.1710087213.600bf98cbba4.26.17.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution2/events.out.tfevents.1710087108.600bf98cbba4.26.15.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution2/train/events.out.tfevents.1710087109.600bf98cbba4.26.16.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution0/validation/events.out.tfevents.1710084978.600bf98cbba4.26.11.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution0/events.out.tfevents.1710084869.600bf98cbba4.26.9.v2',
#  '/kaggle/working/logs/cifakeCNN20240310-144409/6/execution0/train/events.out.tfevents.1710084870.600bf98cbba4.26.10.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution1/events.out.tfevents.1709991805.5ac0aa57c300.25.3.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution1/validation/events.out.tfevents.1709991910.5ac0aa57c300.25.5.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution1/train/events.out.tfevents.1709991805.5ac0aa57c300.25.4.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution2/validation/events.out.tfevents.1709992732.5ac0aa57c300.25.8.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution2/events.out.tfevents.1709992625.5ac0aa57c300.25.6.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution2/train/events.out.tfevents.1709992626.5ac0aa57c300.25.7.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution0/events.out.tfevents.1709990844.5ac0aa57c300.25.0.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution0/validation/events.out.tfevents.1709991082.5ac0aa57c300.25.2.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/3/execution0/train/events.out.tfevents.1709990845.5ac0aa57c300.25.1.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution1/validation/events.out.tfevents.1709994560.5ac0aa57c300.25.14.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution1/events.out.tfevents.1709994460.5ac0aa57c300.25.12.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution1/train/events.out.tfevents.1709994461.5ac0aa57c300.25.13.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution2/validation/events.out.tfevents.1709995631.5ac0aa57c300.25.17.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution2/events.out.tfevents.1709995531.5ac0aa57c300.25.15.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution2/train/events.out.tfevents.1709995532.5ac0aa57c300.25.16.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution0/validation/events.out.tfevents.1709993539.5ac0aa57c300.25.11.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution0/events.out.tfevents.1709993434.5ac0aa57c300.25.9.v2',
#  '/kaggle/working/logs/cifakeCNN20240309-132543/4/execution0/train/events.out.tfevents.1709993435.5ac0aa57c300.25.10.v2',
#  '/kaggle/working/best/best_model_20240309-132721.keras',
#  '/kaggle/working/best/best_model_20240310-144624.keras',
#  '/kaggle/working/best/best_model_20240310-211147.keras',
#  '/kaggle/working/BESTcifakeCNN20240309-132543.keras']

# %%
NAME = "cifakeCNN{}".format(time.strftime("%Y%m%d-%H%M%S"))

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)

# %%
# tf.config.threading.set_intra_op_parallelism_threads(1)
# tf.config.threading.set_inter_op_parallelism_threads(1)

# %%
ds_train = image_dataset_from_directory(
    '/kaggle/input/cifake-real-and-ai-generated-synthetic-images/train',
    labels='inferred',
    label_mode='binary',
    image_size=[32,32],
    interpolation='nearest',
    batch_size=32,
    shuffle=True,
    seed=69,
    #validation_split=None,
    subset=None,
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 100000 files belonging to 2 classes.

# %%
ds_test = image_dataset_from_directory(
    '/kaggle/input/cifake-real-and-ai-generated-synthetic-images/test',
    labels='inferred',
    label_mode='binary',
    image_size=[32,32],
    interpolation='nearest',
    batch_size=32,
    shuffle=True,
    seed=69,
    #validation_split=None,
    subset=None,
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 20000 files belonging to 2 classes.

# %%
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
ds_train = (
    ds_train
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# %%
ds_valid = (
    ds_test
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    min_delta=0.001,
    restore_best_weights=True)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=6, min_lr=0.0008)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
timestamp = time.strftime("%Y%m%d-%H%M%S")
model_checkpoint = ModelCheckpoint(
    f'/kaggle/working/best/best_model_{timestamp}.keras', monitor='val_loss', save_best_only=True, mode='min'
)

# %%
def MBConv6(input_tensor, hp=None, out_channels=32, expansion=6, use_se=True, dropout_rate=0.0):
    # Inverted Residual Structure
    # Pointwise Convolution  1 with Expansion Factor  6
    x = layers.Conv2D(expansion * input_tensor.shape[-1], (1,  1), padding='same', use_bias=False)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x)

    # Depthwise Separable Convolution with stride (1,  1)
    x = layers.DepthwiseConv2D(kernel_size=(3,  3), strides=(1,  1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x)

    # Pointwise Convolution  2
    x = layers.Conv2D(out_channels, (1,  1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Dropout
    if dropout_rate >  0.0:
        x = layers.Dropout(dropout_rate)(x)

    # Bottleneck Convolution  
    x = layers.Conv2D(out_channels, (1,  1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Squeeze-and-Excitation
    if use_se:
        se_shape = (1,  1, out_channels)
        se = layers.GlobalAveragePooling2D()(x)
        se = layers.Reshape(se_shape)(se)
        se = layers.Conv2D(out_channels //  4, (1,  1), padding='same', use_bias=True)(se)
        se = layers.Activation(swish)(se)
        se = layers.Conv2D(out_channels, (1,  1), padding='same', use_bias=True)(se)
        se = layers.Activation('sigmoid')(se)
        x = layers.Multiply()([x, se])

    # Residual
    if input_tensor.shape[-1] == out_channels:
        shortcut = input_tensor
    else:
        shortcut = layers.Conv2D(out_channels, (1,  1), strides=(1,  1), padding='same', use_bias=False)(input_tensor)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])

    return x
input_tensor = layers.Input(shape=(32,  32,  16)) 
output_tensor = MBConv6(input_tensor)
model = keras.models.Model(inputs=input_tensor, outputs=output_tensor)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32,    │          0 │ -                 │
# │ (InputLayer)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      1,536 │ input_layer[0][0] │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        384 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 32, 32,    │        864 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │      3,072 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      1,024 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 1, 1, 8)   │        264 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1, 1, 8)   │          0 │ conv2d_3[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 1, 1, 32)  │        288 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1, 1, 32)  │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │        512 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ multiply[0][0],   │
# │                     │ 32)               │            │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,712 (34.03 KB)
#  Trainable params: 8,136 (31.78 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
def MBConv1(input_tensor, hp=None, expansion=4, out_channels=16, dropout_rate=0.0, strides=(1,   1), use_se=True):
    # Expansion
    x = layers.Conv2D(expansion, (1,   1), padding='same', use_bias=False)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x)

    # Depthwise 
    x = layers.DepthwiseConv2D(kernel_size=(3,   3), strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x) 

    # Pointwise 
    x = layers.Conv2D(out_channels, (1,   1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    # Dropout
    if dropout_rate >  0.0:
        x = layers.Dropout(dropout_rate)(x)
    # Squeeze-and-Excitation
    if use_se:
        se_shape = (1,  1, out_channels)
        se = layers.GlobalAveragePooling2D()(x)
        se = layers.Reshape((1,  1, out_channels))(se) 
        se = layers.Conv2D(out_channels //  2, (1,  1), padding='same', use_bias=True)(se) 
        se = layers.Activation(swish)(se)   
        se = layers.Conv2D(out_channels, (1,  1), padding='same', use_bias=True)(se) 
        se = layers.Activation('sigmoid')(se)
        se = layers.Reshape(se_shape[1:])(se)  # Reshape to original
        x = layers.Multiply()([x, se])

    # Residual
    if input_tensor.shape[-1] == out_channels and strides == (1,   1):
        x = layers.Add()([x, input_tensor])
    else:
        input_tensor = layers.Conv2D(out_channels, (1,   1), strides=strides, padding='same', use_bias=False)(input_tensor)
        x = layers.Add()([x, input_tensor])

    return x

input_tensor = layers.Input(shape=(32,  32,  3)) 
output_tensor = MBConv1(input_tensor)
model = keras.models.Model(inputs=input_tensor, outputs=output_tensor)

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32, 4) │         12 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 4) │         16 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32, 4) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 32, 32, 4) │         36 │ activation_4[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 4) │         16 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32, 4) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │         64 │ activation_5[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 16)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 1, 1, 8)   │        136 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 1, 1, 8)   │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 1, 1, 16)  │        144 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 1, 1, 16)  │          0 │ conv2d_9[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 16)     │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 16)               │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │         48 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ multiply_1[0][0], │
# │                     │ 16)               │            │ conv2d_10[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 536 (2.09 KB)
#  Trainable params: 488 (1.91 KB)
#  Non-trainable params: 48 (192.00 B)

# %%
import keras_tuner
from keras_tuner import RandomSearch, Hyperband
from tensorflow.keras.models import Model

def build_model(hp=None):
    activation_function = 'leaky_relu' if hp.Boolean(f'use_leaky_relu') else 'relu'
    input_tensor = layers.Input(shape=[32,  32,  3])
    if hp.Boolean('use_preprocessing'):
        x = layers.RandomRotation(factor=hp.Float('pre_rotation', min_value=0.0, max_value=0.2232, step=0.0744))(input_tensor)
        x = layers.RandomTranslation(height_factor=hp.Float('pre_rotation', min_value=0.0, max_value=0.1035, step=0.0345), width_factor=0.069)(x)
        x = layers.RandomFlip(mode='horizontal')(x)
        x = layers.BatchNormalization()(x)
    if not hp.Boolean('use_preprocessing'):
        if hp.Boolean('use_pre_conv'):
            x = layers.Conv2D(filters=hp.Int('conv_filter', min_value=32, max_value=96, step=32),
                          kernel_size=hp.Choice('pre_conv_kernel', values=[3, 5]),
                          activation=activation_function, padding='same',
                          kernel_regularizer=keras.regularizers.l2(hp.Choice('l2_reg_value', values=[0.0, 0.003, 0.006, 0.009])) if hp.Boolean('l2_reg') else None)(input_tensor)
    else:
        if hp.Boolean('use_pre_conv'):
            x = layers.Conv2D(filters=hp.Int('conv_filter', min_value=32, max_value=96, step=32),
                          kernel_size=hp.Choice('pre_conv_kernel', values=[3, 5]),
                          activation=activation_function, padding='same',
                          kernel_regularizer=keras.regularizers.l2(hp.Choice('l2_reg_value', values=[0.0, 0.003, 0.006, 0.009])) if hp.Boolean('l2_reg') else None)(x)
            x = layers.Dropout(hp.Float(f'dropout_rate_conv_1', min_value=0.0, max_value=0.15, step=0.15))(x)
    if not hp.Boolean('use_preprocessing') and not hp.Boolean('use_pre_conv'):
        if hp.Boolean('use_mbconv1'):
            x = MBConv1(input_tensor, hp=hp, dropout_rate=hp.Float('conv1_dropout_rate', min_value=0.0, max_value=0.2, step=0.1))
    else:
        if hp.Boolean('use_mbconv1'):
            x = MBConv1(x, hp=hp, dropout_rate=hp.Float('conv1_dropout_rate', min_value=0.0, max_value=0.2, step=0.1)) 
              

    if not hp.Boolean('use_preprocessing') and not hp.Boolean('use_pre_conv') and not hp.Boolean('use_mbconv1'):
        x = MBConv6(input_tensor, hp=hp, out_channels=hp.Int('out_channels_1', min_value=20, max_value=44, step=12),
                expansion=hp.Int('expansion_1', min_value=4, max_value=8, step=2),
                use_se=hp.Boolean('use_se_1'),
                dropout_rate=hp.Float('conv6_dropout_rate_1', min_value=0.0, max_value=0.2, step=0.1))
    else:
        x = MBConv6(x, hp=hp, out_channels=hp.Int('out_channels_1', min_value=20, max_value=44, step=12),
                expansion=hp.Int('expansion_1', min_value=4, max_value=8, step=2),
                use_se=hp.Boolean('use_se_1'),
                dropout_rate=hp.Float('conv6_dropout_rate_1', min_value=0.0, max_value=0.2, step=0.1))
        
    x = layers.Dropout(hp.Float('dropout_rate_conv_2', min_value=0.0, max_value=0.15, step=0.15))(x)
    if hp.Boolean('use_more_mbconv'):
        x = MBConv6(x, hp=hp, out_channels=hp.Int('out_channels_2', min_value=20, max_value=44, step=12),
                expansion=hp.Int('expansion_2', min_value=4, max_value=8, step=2),
                use_se=hp.Boolean('use_se_2'),
                dropout_rate=hp.Float('conv6_dropout_rate_2', min_value=0.0, max_value=0.2, step=0.1))
        x = layers.Dropout(hp.Float(f'dropout_rate_conv', min_value=0.0, max_value=0.15, step=0.15))(x)
    # if hp.Boolean('use_post_conv'):
    x = layers.Conv2D(filters=hp.Int('conv_filter_1', min_value=32, max_value=96, step=32),
                      kernel_size=hp.Choice('conv_kernel_1', values=[3, 5,  7]),
                      activation=activation_function, padding='same',
                      kernel_regularizer=keras.regularizers.l2(hp.Choice('l2_reg_value', values=[0.0, 0.003, 0.006, 0.009])) if hp.Boolean('l2_reg') else None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(hp.Float(f'dropout_rate_conv_3', min_value=0.0, max_value=0.2, step=0.1))(x)
    x = layers.Conv2D(filters=hp.Int('conv_filter_2', min_value=32, max_value=96, step=32),
                      kernel_size=hp.Choice('conv_kernel_2', values=[3, 5,  7]),
                      activation=activation_function, padding='same',
                      kernel_regularizer=keras.regularizers.l2(hp.Choice('l2_reg_value', values=[0.0, 0.003, 0.006, 0.009])) if hp.Boolean('l2_reg') else None)(x)
    x = layers.Dropout(hp.Float(f'dropout_rate_conv_3', min_value=0.0, max_value=0.2, step=0.1))(x)
    for i in range(hp.Int('num_maxpool', min_value=1, max_value=3, step=1)):
        x = layers.MaxPool2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Flatten()(x)
    

    for i in range(hp.Int('num_dense_layers', min_value=4, max_value=10, step=2)):   
        x = layers.Dense(hp.Int(f'dense_units', min_value=256, max_value=512, step=128),
                         activation=activation_function,
                         kernel_regularizer=keras.regularizers.l2(hp.Choice('l2_reg_value', values=[0.0, 0.003, 0.006, 0.009])) if hp.Boolean('l2_reg') else None)(x)
        x = layers.Dropout(hp.Float(f'dropout_rate', min_value=0.0, max_value=0.3, step=0.1))(x)
    
    x = layers.Dense(1, activation='sigmoid')(x)
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=hp.Float('learning_rate', min_value=0.001, max_value=0.05, sampling='LOG'),
                                         epsilon=0.01)
    model = Model(inputs=input_tensor, outputs=x)
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['binary_accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_binary_accuracy',
    max_trials=16,
    executions_per_trial=3,
    directory='/kaggle/working/projects',
    project_name='cifake_random_1')
#destination_dir from /kaggle/input/random-tuner-1-1/cifake_random_1
# Out:
# Reloading Tuner from /kaggle/working/projects/cifake_random_1/tuner0.json

# %%
# Start the hyperparameter search with early stopping
#tuner.load_model('/PROPERPATH/my_tuner_state_1.keras')
tuner.search(ds_train, epochs=45, validation_data=ds_valid, callbacks=[early_stopping, tensorboard, reduce_lr, model_checkpoint])

best_model = tuner.get_best_models(num_models=1)[0]
# Out:
# Trial 16 Complete [00h 31m 54s]
# val_binary_accuracy: 0.9016666611035665
#
# Best val_binary_accuracy So Far: 0.9548666675885519
# Total elapsed time: 2d 17h 20m 25s
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 146 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in /kaggle/working/projects/cifake_random_1
# Showing 10 best trials
# Objective(name="val_binary_accuracy", direction="max")
#
# Trial 11 summary
# Hyperparameters:
# use_leaky_relu: False
# use_preprocessing: False
# use_pre_conv: True
# use_mbconv1: True
# out_channels_1: 32
# expansion_1: 4
# use_se_1: True
# conv6_dropout_rate_1: 0.2
# dropout_rate_conv_2: 0.15
# use_more_mbconv: True
# conv_filter_1: 64
# conv_kernel_1: 7
# l2_reg: False
# dropout_rate_conv_3: 0.1
# conv_filter_2: 64
# conv_kernel_2: 5
# num_maxpool: 1
# num_dense_layers: 6
# dense_units: 512
# dropout_rate: 0.0
# learning_rate: 0.0125
# pre_rotation: 0.22319999999999998
# conv_filter: 64
# pre_conv_kernel: 3
# dropout_rate_conv_1: 0.0
# out_channels_2: 44
# expansion_2: 6
# use_se_2: False
# conv6_dropout_rate_2: 0.1
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.2
# l2_reg_value: 0.0
# Score: 0.9548666675885519
#
# Trial 5 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: False
# use_pre_conv: True
# use_mbconv1: True
# out_channels_1: 32
# expansion_1: 6
# use_se_1: True
# conv6_dropout_rate_1: 0.0
# dropout_rate_conv_2: 0.0
# use_more_mbconv: True
# conv_filter_1: 64
# conv_kernel_1: 3
# l2_reg: False
# dropout_rate_conv_3: 0.0
# conv_filter_2: 32
# conv_kernel_2: 7
# num_maxpool: 2
# num_dense_layers: 4
# dense_units: 256
# dropout_rate: 0.2
# learning_rate: 0.0125
# pre_rotation: 0.22319999999999998
# conv_filter: 64
# pre_conv_kernel: 5
# dropout_rate_conv_1: 0.15
# out_channels_2: 44
# expansion_2: 6
# use_se_2: False
# conv6_dropout_rate_2: 0.2
# dropout_rate_conv: 0.0
# conv1_dropout_rate: 0.0
# l2_reg_value: 0.003
# Score: 0.9461833238601685
#
# Trial 14 summary
# Hyperparameters:
# use_leaky_relu: False
# use_preprocessing: True
# use_pre_conv: False
# use_mbconv1: True
# out_channels_1: 44
# expansion_1: 4
# use_se_1: False
# conv6_dropout_rate_1: 0.1
# dropout_rate_conv_2: 0.15
# use_more_mbconv: True
# conv_filter_1: 32
# conv_kernel_1: 5
# l2_reg: False
# dropout_rate_conv_3: 0.1
# conv_filter_2: 64
# conv_kernel_2: 3
# num_maxpool: 3
# num_dense_layers: 10
# dense_units: 512
# dropout_rate: 0.0
# learning_rate: 0.02
# pre_rotation: 0.0
# conv_filter: 32
# pre_conv_kernel: 3
# dropout_rate_conv_1: 0.0
# out_channels_2: 32
# expansion_2: 6
# use_se_2: True
# conv6_dropout_rate_2: 0.2
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.0
# l2_reg_value: 0.003
# Score: 0.9382333358128866
#
# Trial 0 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: True
# use_pre_conv: True
# use_mbconv1: False
# out_channels_1: 32
# expansion_1: 4
# use_se_1: False
# conv6_dropout_rate_1: 0.2
# dropout_rate_conv_2: 0.0
# use_more_mbconv: True
# conv_filter_1: 64
# conv_kernel_1: 5
# l2_reg: False
# dropout_rate_conv_3: 0.0
# conv_filter_2: 64
# conv_kernel_2: 7
# num_maxpool: 2
# num_dense_layers: 6
# dense_units: 256
# dropout_rate: 0.2
# learning_rate: 0.025
# pre_rotation: 0.0
# conv_filter: 32
# pre_conv_kernel: 3
# dropout_rate_conv_1: 0.0
# out_channels_2: 20
# expansion_2: 4
# use_se_2: False
# conv6_dropout_rate_2: 0.0
# dropout_rate_conv: 0.0
# Score: 0.9155166745185852
#
# Trial 15 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: False
# use_pre_conv: False
# use_mbconv1: False
# out_channels_1: 20
# expansion_1: 6
# use_se_1: True
# conv6_dropout_rate_1: 0.2
# dropout_rate_conv_2: 0.0
# use_more_mbconv: False
# conv_filter_1: 64
# conv_kernel_1: 7
# l2_reg: True
# dropout_rate_conv_3: 0.2
# conv_filter_2: 96
# conv_kernel_2: 5
# num_maxpool: 3
# num_dense_layers: 4
# dense_units: 512
# dropout_rate: 0.1
# learning_rate: 0.005
# pre_rotation: 0.22319999999999998
# conv_filter: 64
# pre_conv_kernel: 3
# dropout_rate_conv_1: 0.15
# out_channels_2: 32
# expansion_2: 4
# use_se_2: True
# conv6_dropout_rate_2: 0.1
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.0
# l2_reg_value: 0.009
# Score: 0.9016666611035665
#
# Trial 13 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: False
# use_pre_conv: False
# use_mbconv1: False
# out_channels_1: 44
# expansion_1: 4
# use_se_1: True
# conv6_dropout_rate_1: 0.0
# dropout_rate_conv_2: 0.15
# use_more_mbconv: True
# conv_filter_1: 32
# conv_kernel_1: 7
# l2_reg: True
# dropout_rate_conv_3: 0.2
# conv_filter_2: 64
# conv_kernel_2: 3
# num_maxpool: 1
# num_dense_layers: 10
# dense_units: 384
# dropout_rate: 0.1
# learning_rate: 0.030000000000000002
# pre_rotation: 0.1488
# conv_filter: 96
# pre_conv_kernel: 3
# dropout_rate_conv_1: 0.15
# out_channels_2: 44
# expansion_2: 8
# use_se_2: True
# conv6_dropout_rate_2: 0.1
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.0
# l2_reg_value: 0.003
# Score: 0.7607333262761434
#
# Trial 2 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: False
# use_pre_conv: True
# use_mbconv1: False
# out_channels_1: 44
# expansion_1: 8
# use_se_1: True
# conv6_dropout_rate_1: 0.1
# dropout_rate_conv_2: 0.0
# use_more_mbconv: True
# conv_filter_1: 64
# conv_kernel_1: 3
# l2_reg: False
# dropout_rate_conv_3: 0.2
# conv_filter_2: 64
# conv_kernel_2: 5
# num_maxpool: 2
# num_dense_layers: 4
# dense_units: 512
# dropout_rate: 0.0
# learning_rate: 0.07500000000000001
# pre_rotation: 0.22319999999999998
# conv_filter: 96
# pre_conv_kernel: 5
# dropout_rate_conv_1: 0.15
# out_channels_2: 32
# expansion_2: 8
# use_se_2: False
# conv6_dropout_rate_2: 0.0
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.0
# Score: 0.7586166659990946
#
# Trial 6 summary
# Hyperparameters:
# use_leaky_relu: False
# use_preprocessing: False
# use_pre_conv: True
# use_mbconv1: True
# out_channels_1: 32
# expansion_1: 4
# use_se_1: False
# conv6_dropout_rate_1: 0.0
# dropout_rate_conv_2: 0.0
# use_more_mbconv: True
# conv_filter_1: 96
# conv_kernel_1: 7
# l2_reg: True
# dropout_rate_conv_3: 0.2
# conv_filter_2: 32
# conv_kernel_2: 3
# num_maxpool: 1
# num_dense_layers: 8
# dense_units: 512
# dropout_rate: 0.1
# learning_rate: 0.02
# pre_rotation: 0.22319999999999998
# conv_filter: 96
# pre_conv_kernel: 5
# dropout_rate_conv_1: 0.0
# out_channels_2: 32
# expansion_2: 6
# use_se_2: True
# conv6_dropout_rate_2: 0.0
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.1
# l2_reg_value: 0.009
# Score: 0.7024333477020264
#
# Trial 12 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: False
# use_pre_conv: False
# use_mbconv1: False
# out_channels_1: 44
# expansion_1: 8
# use_se_1: True
# conv6_dropout_rate_1: 0.2
# dropout_rate_conv_2: 0.0
# use_more_mbconv: True
# conv_filter_1: 64
# conv_kernel_1: 3
# l2_reg: False
# dropout_rate_conv_3: 0.1
# conv_filter_2: 64
# conv_kernel_2: 5
# num_maxpool: 1
# num_dense_layers: 6
# dense_units: 384
# dropout_rate: 0.0
# learning_rate: 0.095
# pre_rotation: 0.1488
# conv_filter: 64
# pre_conv_kernel: 5
# dropout_rate_conv_1: 0.15
# out_channels_2: 44
# expansion_2: 8
# use_se_2: False
# conv6_dropout_rate_2: 0.2
# dropout_rate_conv: 0.15
# conv1_dropout_rate: 0.2
# l2_reg_value: 0.009
# Score: 0.651199996471405
#
# Trial 07 summary
# Hyperparameters:
# use_leaky_relu: True
# use_preprocessing: False
# use_pre_conv: False
# use_mbconv1: False
# out_channels_1: 20
# expansion_1: 8
# use_se_1: False
# conv6_dropout_rate_1: 0.1
# dropout_rate_conv_2: 0.15
# use_more_mbconv: True
# conv_filter_1: 64
# conv_kernel_1: 5
# l2_reg: False
# dropout_rate_conv_3: 0.2
# conv_filter_2: 96
# conv_kernel_2: 7
# num_maxpool: 2
# num_dense_layers: 10
# dense_units: 384
# dropout_rate: 0.1
# learning_rate: 0.0775
# pre_rotation: 0.0
# conv_filter: 64
# pre_conv_kernel: 5
# dropout_rate_conv_1: 0.15
# out_channels_2: 20
# expansion_2: 6
# use_se_2: False
# conv6_dropout_rate_2: 0.0
# dropout_rate_conv: 0.0
# conv1_dropout_rate: 0.0
# l2_reg_value: 0.003
# Score: 0.5002333323160807

# %%
best_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32, 4) │        256 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32, 4) │         16 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32, 4) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 32, 32, 4) │         36 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 4) │         16 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32, 4) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │         64 │ activation_1[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ dropout[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 16)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 1, 1, 8)   │        136 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1, 1, 8)   │          0 │ conv2d_3[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 1, 1, 16)  │        144 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1, 1, 16)  │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 16)     │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ dropout[0][0],    │
# │                     │ 16)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │      1,024 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ multiply[0][0],   │
# │                     │ 16)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │      1,024 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 32, 32,    │        576 │ activation_4[0][… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │      2,048 │ activation_5[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      1,024 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 32)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 1, 1, 8)   │        264 │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 1, 1, 8)   │          0 │ conv2d_9[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 1, 1, 32)  │        288 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 1, 1, 32)  │          0 │ conv2d_10[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │        512 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 32)               │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ multiply_1[0][0], │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │      6,144 │ dropout_2[0][0]   │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        768 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 32, 32,    │      1,728 │ activation_8[0][… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      8,448 │ activation_9[0][… │
# │                     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        176 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │      1,936 │ dropout_3[0][0]   │
# │                     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │      1,408 │ dropout_2[0][0]   │
# │                     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        176 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        176 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 44)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │                     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 32, 32,    │    138,048 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │    102,464 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_17[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 8, 8, 64)  │          0 │ dropout_6[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ max_pooling2d_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 4096)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │  2,097,664 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    262,656 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 512)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 512)       │    262,656 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 512)       │          0 │ dense_3[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 512)       │    262,656 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 512)       │          0 │ dense_4[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 512)       │    262,656 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 512)       │          0 │ dense_5[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1)         │        513 │ dropout_12[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,684,389 (14.05 MB)
#  Trainable params: 3,682,605 (14.05 MB)
#  Non-trainable params: 1,784 (6.97 KB)

# %%
best_model.save(f"/kaggle/working/BEST{NAME}.keras")
